# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import plotly.graph_objs as go 
import plotly.offline as py 
import math
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# ## Fetch Dataset
#
# This is elliptic++ dataset, the following data preprocessing are all for elliptic++. For elliptic, please do your own implementation

# %%
import gdown
# !gdown --fuzzy "https://drive.google.com/file/d/19q09IFhfkOOBOXvn_dKhWjILJtjCcsjc/view?usp=drive_link"
# !gdown --fuzzy "https://drive.google.com/file/d/1DiBxn8TXdbJqoSw58pYUeaqO3oOKhuQO/view?usp=drive_link"
# !gdown --fuzzy "https://drive.google.com/file/d/1Q2yG_CIDvfdGP-fKVPSw979EYgQukjz5/view?usp=drive_link"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=19q09IFhfkOOBOXvn_dKhWjILJtjCcsjc
# From (redirected): https://drive.google.com/uc?id=19q09IFhfkOOBOXvn_dKhWjILJtjCcsjc&confirm=t&uuid=f7f9bb03-4594-4f57-bde1-1640246738ab
# To: /home/kingjames23/EllipticPlusPlus/Transactions Dataset/txs_features.csv
# 100%|████████████████████████████████████████| 695M/695M [00:21<00:00, 32.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1DiBxn8TXdbJqoSw58pYUeaqO3oOKhuQO
# To: /home/kingjames23/EllipticPlusPlus/Transactions Dataset/txs_classes.csv
# 100%|██████████████████████████████████████| 2.36M/2.36M [00:00<00:00, 92.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Q2yG_CIDvfdGP-fKVPSw979EYgQukjz5
# To: /home/kingjames23/EllipticPlusPlus/Transactions Dataset/txs_edgelist.csv
# 100%|██████████████████████████████████████| 4.47M/4.47M [00:00<00:00, 17.6MB/s]

# %%
print("\nTransaction features: \n")
df_txs_features = pd.read_csv("txs_features.csv")
df_txs_features

print("\nTransaction classes: \n")
df_txs_classes = pd.read_csv("txs_classes.csv")
df_txs_classes

print("\nTransaction-Transaction edgelist: \n")
df_txs_edgelist = pd.read_csv("txs_edgelist.csv")
df_txs_edgelist
# Out:
# Transaction features:
#
#
# Transaction classes:
#
#
# Transaction-Transaction edgelist:
#             txId1      txId2
# 0       230425980    5530458
# 1       232022460  232438397
# 2       230460314  230459870
# 3       230333930  230595899
# 4       232013274  232029206
# ...           ...        ...
# 234350  158365409  157930723
# 234351  188708874  188708879
# 234352  157659064  157659046
# 234353   87414554  106877725
# 234354  158589452  158589457
#
# [234355 rows x 2 columns]

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# 1. Drop nodes (transactions) without augmented feature values (0.5% not de-anonymized)
# 2. Drop edges accordingly

# %%
# 1. 把 feature DataFrame 裡含 NaN 的行丟掉
df_txs_features_droped = df_txs_features.dropna()
# 2. 取出還在的 txId（假設 index 就是 txId）
valid_tx = set(df_txs_features_droped.txId)

# 3. 篩邊表：只保留 txId1 與 txId2 都在 valid_tx 裡面的邊
df_txs_edgelist = df_txs_edgelist[
    df_txs_edgelist['txId1'].isin(valid_tx) &
    df_txs_edgelist['txId2'].isin(valid_tx)
].reset_index(drop=True)

# %%
df_txs_edgelist
# Out:
#             txId1      txId2
# 0       230425980    5530458
# 1       232022460  232438397
# 2       230460314  230459870
# 3       230333930  230595899
# 4       232013274  232029206
# ...           ...        ...
# 233278  158365409  157930723
# 233279  188708874  188708879
# 233280  157659064  157659046
# 233281   87414554  106877725
# 233282  158589452  158589457
#
# [233283 rows x 2 columns]

# %% [markdown]
# 3. Merge label into txs_features for later index mapping

# %%
subset = df_txs_classes[['txId', 'class']]

# 2. 用 merge 把 class 欄併到 txs_features
df_txs_features_droped_merged = df_txs_features_droped.merge(
    subset,
    on='txId',     # 以 txId 當作 key
    how='left'     # 保留 txs_features 所有列，對不到的 class 欄會是 NaN
)

# %%
df_txs_features_droped_merged
# Out:
#              txId  Time step  Local_feature_1  Local_feature_2  \
# 0            3321          1        -0.169615        -0.184668
# 1           11108          1        -0.137586        -0.184668
# 2           51816          1        -0.170103        -0.184668
# 3           68869          1        -0.114267        -0.184668
# 4           89273          1         5.202107        -0.210553
# ...           ...        ...              ...              ...
# 202799  194747812         49         0.558398        -0.198956
# 202800  194747925         49         0.547658        -0.198956
# 202801  194748063         49         0.543600        -0.198853
# 202802  194748070         49         0.537760        -0.198853
# 202803  194835939         49        -0.170463        -0.152788
#
#         Local_feature_3  Local_feature_4  Local_feature_5  Local_feature_6  \
# 0             -1.201369        -0.121970        -0.043875        -0.113002
# 1             -1.201369        -0.121970        -0.043875        -0.113002
# 2             -1.201369        -0.121970        -0.043875        -0.113002
# 3             -1.201369         0.028105        -0.043875        -0.113002
# 4             -1.756361        -0.121970       260.090707        -0.113002
# ...                 ...              ...              ...              ...
# 202799        -0.091383        -0.121970        -0.043875        -0.113002
# 202800        -0.091383        -0.121970        -0.043875        -0.113002
# 202801        -0.091383        -0.121970        -0.043875        -0.113002
# 202802        -0.091383        -0.121970        -0.043875        -0.113002
# 202803         1.018602        -0.121970        -0.063725        -0.113002
#
#         Local_feature_7  Local_feature_8  ...  in_BTC_max  in_BTC_mean  \
# 0             -0.061584        -0.160199  ...    0.534072     0.534072
# 1             -0.061584        -0.127429  ...    5.611878     5.611878
# 2             -0.061584        -0.160699  ...    0.456608     0.456608
# 3              0.547008        -0.161652  ...    8.000000     3.102967
# 4             -0.061584         5.335864  ...  852.164680   852.164680
# ...                 ...              ...  ...         ...          ...
# 202799        -0.061584         0.584665  ...  115.952889   115.952889
# 202800        -0.061584         0.573676  ...  114.250098   114.250098
# 202801        -0.061584         0.569524  ...  113.606771   113.606771
# 202802        -0.061584         0.563549  ...  112.680977   112.680977
# 202803        -0.061584        -0.161066  ...    0.399769     0.399769
#
#         in_BTC_median  in_BTC_total   out_BTC_min  out_BTC_max  out_BTC_mean  \
# 0            0.534072      0.534072  1.668990e-01     0.367074      0.266986
# 1            5.611878      5.611878  5.861940e-01     5.025584      2.805889
# 2            0.456608      0.456608  2.279902e-01     0.228518      0.228254
# 3            1.000000      9.308900  1.229000e+00     8.079800      4.654400
# 4          852.164680    852.164680  1.300000e-07    41.264036      0.065016
# ...               ...           ...           ...          ...           ...
# 202799     115.952889    115.952889  1.653300e+00   114.299544     57.976422
# 202800     114.250098    114.250098  2.035300e-02   114.229700     57.125027
# 202801     113.606771    113.606771  9.257490e-01   112.680977     56.803363
# 202802     112.680977    112.680977  3.026970e-01   112.378235     56.340466
# 202803       0.399769      0.399769  3.995460e-01     0.399546      0.399546
#
#         out_BTC_median  out_BTC_total  class
# 0             0.266986       0.533972      3
# 1             2.805889       5.611778      3
# 2             0.228254       0.456508      3
# 3             4.654400       9.308800      2
# 4             0.000441     852.164680      2
# ...                ...            ...    ...
# 202799       57.976422     115.952844      3
# 202800       57.125027     114.250053      3
# 202801       56.803363     113.606726      3
# 202802       56.340466     112.680932      3
# 202803        0.399546       0.399546      3
#
# [202804 rows x 185 columns]

# %% [markdown]
# 4. Normalize augmented features

# %%
# For notmalize augmented features
from sklearn.preprocessing import MinMaxScaler

for column in df_txs_features_droped_merged.columns[-18:-1]:
    scaler = MinMaxScaler()
    df_txs_features_droped_merged[column] = scaler.fit_transform(df_txs_features_droped_merged[[column]])

# %%
df_txs_features_droped_merged
# Out:
#              txId  Time step  Local_feature_1  Local_feature_2  \
# 0            3321          1        -0.169615        -0.184668
# 1           11108          1        -0.137586        -0.184668
# 2           51816          1        -0.170103        -0.184668
# 3           68869          1        -0.114267        -0.184668
# 4           89273          1         5.202107        -0.210553
# ...           ...        ...              ...              ...
# 202799  194747812         49         0.558398        -0.198956
# 202800  194747925         49         0.547658        -0.198956
# 202801  194748063         49         0.543600        -0.198853
# 202802  194748070         49         0.537760        -0.198853
# 202803  194835939         49        -0.170463        -0.152788
#
#         Local_feature_3  Local_feature_4  Local_feature_5  Local_feature_6  \
# 0             -1.201369        -0.121970        -0.043875        -0.113002
# 1             -1.201369        -0.121970        -0.043875        -0.113002
# 2             -1.201369        -0.121970        -0.043875        -0.113002
# 3             -1.201369         0.028105        -0.043875        -0.113002
# 4             -1.756361        -0.121970       260.090707        -0.113002
# ...                 ...              ...              ...              ...
# 202799        -0.091383        -0.121970        -0.043875        -0.113002
# 202800        -0.091383        -0.121970        -0.043875        -0.113002
# 202801        -0.091383        -0.121970        -0.043875        -0.113002
# 202802        -0.091383        -0.121970        -0.043875        -0.113002
# 202803         1.018602        -0.121970        -0.063725        -0.113002
#
#         Local_feature_7  Local_feature_8  ...  in_BTC_max  in_BTC_mean  \
# 0             -0.061584        -0.160199  ...    0.000047     0.000047
# 1             -0.061584        -0.127429  ...    0.000493     0.000493
# 2             -0.061584        -0.160699  ...    0.000040     0.000040
# 3              0.547008        -0.161652  ...    0.000702     0.000272
# 4             -0.061584         5.335864  ...    0.074805     0.074805
# ...                 ...              ...  ...         ...          ...
# 202799        -0.061584         0.584665  ...    0.010179     0.010179
# 202800        -0.061584         0.573676  ...    0.010029     0.010029
# 202801        -0.061584         0.569524  ...    0.009973     0.009973
# 202802        -0.061584         0.563549  ...    0.009891     0.009891
# 202803        -0.061584        -0.161066  ...    0.000035     0.000035
#
#         in_BTC_median  in_BTC_total   out_BTC_min  out_BTC_max  out_BTC_mean  \
# 0            0.000047      0.000047  8.301504e-05     0.000032      0.000089
# 1            0.000493      0.000493  2.915711e-04     0.000444      0.000936
# 2            0.000040      0.000040  1.134016e-04     0.000020      0.000076
# 3            0.000088      0.000817  6.113009e-04     0.000714      0.001552
# 4            0.074805      0.074805  6.466160e-11     0.003648      0.000022
# ...               ...           ...           ...          ...           ...
# 202799       0.010179      0.010179  8.223464e-04     0.010104      0.019336
# 202800       0.010029      0.010029  1.012352e-05     0.010098      0.019052
# 202801       0.009973      0.009973  4.604647e-04     0.009961      0.018945
# 202802       0.009891      0.009891  1.505606e-04     0.009935      0.018790
# 202803       0.000035      0.000035  1.987330e-04     0.000035      0.000133
#
#         out_BTC_median  out_BTC_total  class
# 0         8.904096e-05       0.000047      3
# 1         9.357923e-04       0.000493      3
# 2         7.612341e-05       0.000040      3
# 3         1.552291e-03       0.000817      2
# 4         1.451405e-07       0.074805      2
# ...                ...            ...    ...
# 202799    1.933576e-02       0.010179      3
# 202800    1.905181e-02       0.010029      3
# 202801    1.894453e-02       0.009973      3
# 202802    1.879015e-02       0.009891      3
# 202803    1.332511e-04       0.000035      3
#
# [202804 rows x 185 columns]

# %% [markdown]
# 5. Set `txId` as the index for the processed DataFrame
# 6. Updates the index of the Dataframe with ```id_map```
# 7. Constructs `edge_index`

# %%
import torch

df_txs_features_processed = df_txs_features_droped_merged.set_index('txId')

ids_from_src      = df_txs_edgelist['txId1']
ids_from_dst      = df_txs_edgelist['txId2']
all_ids = pd.unique(pd.concat([ids_from_src, ids_from_dst]))
id_map  = {orig_id: idx for idx, orig_id in enumerate(all_ids)}

df_txs_features_processed.index = df_txs_features_processed.index.map(id_map)

src = df_txs_edgelist['txId1'].map(id_map).values
dst = df_txs_edgelist['txId2'].map(id_map).values
edge_index = torch.tensor([src, dst], dtype=torch.long)

# %% [markdown]
# 8. Extract labels and transform `licit` & `unknown`
# 9. Extract time steps and create mask

# %%
y = df_txs_features_processed['class'].copy()
y[y == 2] = 0   # licit
y[y == 3] = 2   # unknown


time_steps = df_txs_features_processed['Time step']

train_mask, test_mask = time_steps <= 34, time_steps > 34
train_mask = torch.tensor(train_mask.to_numpy(), dtype=torch.bool)
test_mask = torch.tensor(test_mask.to_numpy(), dtype=torch.bool)

time_steps = torch.tensor(time_steps.to_numpy(), dtype=torch.int64)

# %%
y
# Out:
# txId
# 166019.0    2
# 2324.0      2
# 6001.0      2
# 6497.0      0
# 66.0        0
#            ..
# 165019.0    2
# 165343.0    2
# 164927.0    2
# 164211.0    2
# 202624.0    2
# Name: class, Length: 202804, dtype: int64

# %% [markdown]
# 10. Drop label & time step

# %%
df_txs_features_final = df_txs_features_processed.drop(columns=['class', 'Time step'])

# %% [markdown]
# Applying PCA

# %%
from sklearn.decomposition import PCA
df_txs_features_final.shape
pca = PCA(n_components=50)
df_txs_features_final = pca.fit_transform(df_txs_features_final)

# Convert back to DataFrame for compatibility
df_txs_features_final = pd.DataFrame(
    df_txs_features_final,
    columns=[f'PC{i+1}' for i in range(df_txs_features_final.shape[1])]
)

# %% [markdown]
# 11. Create raw graph (PyTorch Geometric Data)

# %%
df_txs_features_final.shape
# Out:
# (202804, 182)

# %%
from torch_geometric.data import Data

x = torch.tensor(df_txs_features_final.values, dtype=torch.float)
data = Data(x=x, edge_index=edge_index, y=y, train_mask=train_mask, test_mask=test_mask, node_time=time_steps)
data.y = torch.from_numpy(data.y.to_numpy().astype(int)).long()

# %% [markdown]
# ## Benchmark: RF with only AF
# - Without PCA (highest):
# `Random Forest - Acc: 0.9799, Prec: 0.9678, Rec: 0.7211, F1: 0.8265`
# - With PCA:
# `Random Forest - Acc: 0.9556, Prec: 0.9685, Rec: 0.3407, F1: 0.5041`

# %%
import torch
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

train_mask = (data.y != 2) & data.train_mask
test_mask  = (data.y != 2) & data.test_mask

y_train = data.y[train_mask].cpu().numpy()
y_test  = data.y[test_mask].cpu().numpy()

X_train_af = data.x[train_mask].cpu().numpy()
X_test_af  = data.x[test_mask].cpu().numpy()

rf_af = RandomForestClassifier(n_estimators=100, random_state=42)
rf_af.fit(X_train_af, y_train)

y_pred_af = rf_af.predict(X_test_af)

acc  = accuracy_score(y_test, y_pred_af)
prec = precision_score(y_test, y_pred_af, pos_label=1)
rec  = recall_score(y_test, y_pred_af, pos_label=1)
f1   = f1_score(y_test, y_pred_af, pos_label=1)

print(f"Random Forest - Acc: {acc:.4f}, Prec: {prec:.4f}, Rec: {rec:.4f}, F1: {f1:.4f}")
# Out:
# Random Forest - Acc: 0.9799, Prec: 0.9678, Rec: 0.7211, F1: 0.8265

# %% [markdown]
# ## (i) Naive random splitting on entire graph + joint learning
#
# This approach simply sample negative edge from all edges without considering time step, and it jointly train GAE encoder and classifier without weighted loss or balance data

# %%
from torch_geometric.transforms import RandomLinkSplit

splitter = RandomLinkSplit(
    is_undirected=False,
    split_labels=True,          
    add_negative_train_samples=True,
    neg_sampling_ratio=1.0,
    num_val=0,
    num_test=0,
)
train_data, _, _ = splitter(data)

# %%
print(data.keys())
print(train_data.keys())

for key in ['x', 'y', 'train_mask', 'test_mask', 'node_time', 'edge_index']:
    print(key, torch.equal(getattr(data, key), getattr(train_data, key)))
# Out:
# ['edge_index', 'train_mask', 'y', 'x', 'node_time', 'test_mask']
# ['edge_index', 'pos_edge_label_index', 'neg_edge_label_index', 'train_mask', 'y', 'x', 'node_time', 'test_mask', 'neg_edge_label', 'pos_edge_label']
# x True
# y True
# train_mask True
# test_mask True
# node_time True
# edge_index False

# %%
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv, GAE
from sklearn.metrics import f1_score, precision_score, recall_score

# 2) Encoder + Classifier
class GAEEncoder(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        return self.conv2(x, edge_index)

class NodeClassifier(torch.nn.Module):
    def __init__(self, in_channels, num_classes):
        super().__init__()
        self.lin = torch.nn.Linear(in_channels, num_classes)
    def forward(self, z):
        return self.lin(z)

in_feats    = data.num_node_features
hidden_dim  = 128
out_dim     = 64
num_classes = int(data.y[data.y != 2].max() + 1)

encoder    = GAEEncoder(in_feats, hidden_dim, out_dim)
gae_model  = GAE(encoder)
classifier = NodeClassifier(out_dim, num_classes)

optimizer = torch.optim.Adam(
    list(gae_model.parameters()) + list(classifier.parameters()),
    lr=0.01
)
bce_loss = torch.nn.BCEWithLogitsLoss()
ce_loss  = torch.nn.CrossEntropyLoss()

# 3) train() 改用 train_pos/neg
def train():
    gae_model.train()
    classifier.train()
    optimizer.zero_grad()

    # encode on train positive edges
    z = gae_model.encode(train_data.x, train_data.edge_index)

    # AE loss (pos + neg)
    pos = train_data.pos_edge_label_index
    neg = train_data.neg_edge_label_index
    edge_all = torch.cat([pos, neg], dim=1)
    logits_ae = gae_model.decode(z, edge_all)
    labels_ae = torch.cat([
        torch.ones(pos.size(1), device=logits_ae.device),
        torch.zeros(neg.size(1), device=logits_ae.device),
    ])
    loss_ae = bce_loss(logits_ae, labels_ae)

    # classification loss (only known & train_mask)
    mask = data.train_mask.detach().clone() & (data.y != 2)

    logits_cls = classifier(z)
    loss_cls = ce_loss(logits_cls[mask], train_data.y[mask])

    loss = loss_ae + loss_cls
    loss.backward()
    optimizer.step()

    return loss.item(), loss_ae.item(), loss_cls.item()

# 4) evaluate() 只用 train_data.train_pos_edge_index encode
def evaluate():
   
    with torch.no_grad():
        z = gae_model.encode(train_data.x, train_data.edge_index) 
        logits = classifier(z)
        preds  = logits.argmax(dim=1)
   
        mask = data.test_mask.detach().clone() & (data.y != 2)
  
        y_true = data.y[mask].cpu().numpy()
        y_pred = preds[mask].cpu().numpy()

        acc  = (y_true == y_pred).mean().item()
        prec = precision_score(y_true, y_pred, average='macro', zero_division=0)
        rec  = recall_score(y_true, y_pred, average='macro')
        f1   = f1_score(y_true, y_pred, average='macro')
        print(f"Test Acc={acc:.4f} | "
              f"Precision={prec:.4f} | "
              f"Recall={rec:.4f} | "
              f"F1={f1:.4f}")
        return acc

for epoch in range(1, 101):
    loss_tot, loss_ae, loss_cls = train()
    print(f"Epoch {epoch:03d} | "
              f"Loss={loss_tot:.4f} (AE={loss_ae:.4f}, CLF={loss_cls:.4f})")
    if epoch % 10 == 0:
        test_acc= evaluate()
# Out:
# Epoch 001 | Loss=1.4448 (AE=0.7934, CLF=0.6514)
# Epoch 002 | Loss=1.1494 (AE=0.8093, CLF=0.3401)
# Epoch 003 | Loss=1.2008 (AE=0.8126, CLF=0.3882)
# Epoch 004 | Loss=1.1926 (AE=0.8131, CLF=0.3795)
# Epoch 005 | Loss=1.1544 (AE=0.8132, CLF=0.3412)
# Epoch 006 | Loss=1.1265 (AE=0.8132, CLF=0.3132)
# Epoch 007 | Loss=1.1424 (AE=0.8133, CLF=0.3292)
# Epoch 008 | Loss=1.1344 (AE=0.8133, CLF=0.3211)
# Epoch 009 | Loss=1.1020 (AE=0.8133, CLF=0.2888)
# Epoch 010 | Loss=1.1068 (AE=0.8133, CLF=0.2935)
# Test Acc=0.9337 | Precision=0.4669 | Recall=0.5000 | F1=0.4829
# Epoch 011 | Loss=1.1196 (AE=0.8133, CLF=0.3063)
# Epoch 012 | Loss=1.1130 (AE=0.8133, CLF=0.2998)
# Epoch 013 | Loss=1.0964 (AE=0.8133, CLF=0.2831)
# Epoch 014 | Loss=1.0990 (AE=0.8133, CLF=0.2857)
# Epoch 015 | Loss=1.0975 (AE=0.8133, CLF=0.2843)
# Epoch 016 | Loss=1.0847 (AE=0.8133, CLF=0.2715)
# Epoch 017 | Loss=1.0868 (AE=0.8133, CLF=0.2736)
# Epoch 018 | Loss=1.0896 (AE=0.8133, CLF=0.2764)
# Epoch 019 | Loss=1.0850 (AE=0.8133, CLF=0.2718)
# Epoch 020 | Loss=1.0784 (AE=0.8133, CLF=0.2651)
# Test Acc=0.9143 | Precision=0.6340 | Recall=0.6105 | F1=0.6207
# Epoch 021 | Loss=1.0778 (AE=0.8133, CLF=0.2646)
# Epoch 022 | Loss=1.0764 (AE=0.8133, CLF=0.2631)
# Epoch 023 | Loss=1.0700 (AE=0.8133, CLF=0.2567)
# Epoch 024 | Loss=1.0714 (AE=0.8133, CLF=0.2581)
# Epoch 025 | Loss=1.0711 (AE=0.8133, CLF=0.2579)
# Epoch 026 | Loss=1.0659 (AE=0.8133, CLF=0.2526)
# Epoch 027 | Loss=1.0652 (AE=0.8133, CLF=0.2519)
# Epoch 028 | Loss=1.0615 (AE=0.8133, CLF=0.2483)
# Epoch 029 | Loss=1.0593 (AE=0.8133, CLF=0.2460)
# Epoch 030 | Loss=1.0602 (AE=0.8133, CLF=0.2469)
# Test Acc=0.9207 | Precision=0.6288 | Recall=0.5707 | F1=0.5883
# Epoch 031 | Loss=1.0584 (AE=0.8133, CLF=0.2452)
# Epoch 032 | Loss=1.0558 (AE=0.8133, CLF=0.2425)
# Epoch 033 | Loss=1.0545 (AE=0.8133, CLF=0.2413)
# Epoch 034 | Loss=1.0523 (AE=0.8133, CLF=0.2391)
# Epoch 035 | Loss=1.0524 (AE=0.8133, CLF=0.2391)
# Epoch 036 | Loss=1.0508 (AE=0.8133, CLF=0.2375)
# Epoch 037 | Loss=1.0484 (AE=0.8133, CLF=0.2352)
# Epoch 038 | Loss=1.0475 (AE=0.8133, CLF=0.2342)
# Epoch 039 | Loss=1.0463 (AE=0.8133, CLF=0.2330)
# Epoch 040 | Loss=1.0461 (AE=0.8133, CLF=0.2328)
# Test Acc=0.9207 | Precision=0.6194 | Recall=0.5603 | F1=0.5766
# Epoch 041 | Loss=1.0440 (AE=0.8133, CLF=0.2307)
# Epoch 042 | Loss=1.0429 (AE=0.8133, CLF=0.2296)
# Epoch 043 | Loss=1.0415 (AE=0.8133, CLF=0.2282)
# Epoch 044 | Loss=1.0408 (AE=0.8133, CLF=0.2275)
# Epoch 045 | Loss=1.0389 (AE=0.8133, CLF=0.2256)
# Epoch 046 | Loss=1.0383 (AE=0.8133, CLF=0.2250)
# Epoch 047 | Loss=1.0368 (AE=0.8133, CLF=0.2235)
# Epoch 048 | Loss=1.0362 (AE=0.8133, CLF=0.2229)
# Epoch 049 | Loss=1.0345 (AE=0.8133, CLF=0.2213)
# Epoch 050 | Loss=1.0339 (AE=0.8133, CLF=0.2207)
# Test Acc=0.9169 | Precision=0.6052 | Recall=0.5596 | F1=0.5735
# Epoch 051 | Loss=1.0322 (AE=0.8133, CLF=0.2189)
# Epoch 052 | Loss=1.0313 (AE=0.8133, CLF=0.2181)
# Epoch 053 | Loss=1.0303 (AE=0.8133, CLF=0.2170)
# Epoch 054 | Loss=1.0291 (AE=0.8133, CLF=0.2158)
# Epoch 055 | Loss=1.0283 (AE=0.8133, CLF=0.2150)
# Epoch 056 | Loss=1.0268 (AE=0.8133, CLF=0.2136)
# Epoch 057 | Loss=1.0258 (AE=0.8133, CLF=0.2125)
# Epoch 058 | Loss=1.0246 (AE=0.8133, CLF=0.2113)
# Epoch 059 | Loss=1.0233 (AE=0.8133, CLF=0.2100)
# Epoch 060 | Loss=1.0224 (AE=0.8133, CLF=0.2092)
# Test Acc=0.9174 | Precision=0.6082 | Recall=0.5612 | F1=0.5755
# Epoch 061 | Loss=1.0213 (AE=0.8133, CLF=0.2081)
# Epoch 062 | Loss=1.0198 (AE=0.8133, CLF=0.2065)
# Epoch 063 | Loss=1.0186 (AE=0.8133, CLF=0.2054)
# Epoch 064 | Loss=1.0177 (AE=0.8133, CLF=0.2044)
# Epoch 065 | Loss=1.0161 (AE=0.8133, CLF=0.2029)
# Epoch 066 | Loss=1.0146 (AE=0.8133, CLF=0.2013)
# Epoch 067 | Loss=1.0132 (AE=0.8133, CLF=0.1999)
# Epoch 068 | Loss=1.0121 (AE=0.8133, CLF=0.1988)
# Epoch 069 | Loss=1.0111 (AE=0.8133, CLF=0.1978)
# Epoch 070 | Loss=1.0101 (AE=0.8133, CLF=0.1968)
# Test Acc=0.9197 | Precision=0.6165 | Recall=0.5611 | F1=0.5769
# Epoch 071 | Loss=1.0103 (AE=0.8133, CLF=0.1970)
# Epoch 072 | Loss=1.0102 (AE=0.8133, CLF=0.1970)
# Epoch 073 | Loss=1.0145 (AE=0.8133, CLF=0.2012)
# Epoch 074 | Loss=1.0083 (AE=0.8133, CLF=0.1950)
# Epoch 075 | Loss=1.0047 (AE=0.8133, CLF=0.1914)
# Epoch 076 | Loss=1.0020 (AE=0.8133, CLF=0.1888)
# Epoch 077 | Loss=1.0019 (AE=0.8133, CLF=0.1886)
# Epoch 078 | Loss=1.0022 (AE=0.8133, CLF=0.1890)
# Epoch 079 | Loss=1.0037 (AE=0.8133, CLF=0.1905)
# Epoch 080 | Loss=1.0210 (AE=0.8133, CLF=0.2077)
# Test Acc=0.9022 | Precision=0.6039 | Recall=0.6032 | F1=0.6036
# Epoch 081 | Loss=1.0132 (AE=0.8133, CLF=0.1999)
# Epoch 082 | Loss=1.0051 (AE=0.8133, CLF=0.1918)
# Epoch 083 | Loss=1.0062 (AE=0.8133, CLF=0.1930)
# Epoch 084 | Loss=1.0045 (AE=0.8133, CLF=0.1913)
# Epoch 085 | Loss=1.0039 (AE=0.8133, CLF=0.1907)
# Epoch 086 | Loss=1.0037 (AE=0.8133, CLF=0.1905)
# Epoch 087 | Loss=0.9989 (AE=0.8133, CLF=0.1857)
# Epoch 088 | Loss=1.0010 (AE=0.8133, CLF=0.1878)
# Epoch 089 | Loss=0.9995 (AE=0.8133, CLF=0.1862)
# Epoch 090 | Loss=0.9981 (AE=0.8133, CLF=0.1848)
# Test Acc=0.9171 | Precision=0.6251 | Recall=0.5829 | F1=0.5981
# Epoch 091 | Loss=0.9958 (AE=0.8133, CLF=0.1826)
# Epoch 092 | Loss=0.9955 (AE=0.8133, CLF=0.1822)
# Epoch 093 | Loss=0.9943 (AE=0.8133, CLF=0.1810)
# Epoch 094 | Loss=0.9913 (AE=0.8133, CLF=0.1780)
# Epoch 095 | Loss=0.9903 (AE=0.8133, CLF=0.1771)
# Epoch 096 | Loss=0.9907 (AE=0.8133, CLF=0.1774)
# Epoch 097 | Loss=0.9902 (AE=0.8133, CLF=0.1769)
# Epoch 098 | Loss=0.9920 (AE=0.8133, CLF=0.1787)
# Epoch 099 | Loss=0.9935 (AE=0.8133, CLF=0.1803)
# Epoch 100 | Loss=0.9924 (AE=0.8133, CLF=0.1791)
# Test Acc=0.9002 | Precision=0.5817 | Recall=0.5743 | F1=0.5777

# %% [markdown]
# ## (ii) Single Graph Dataset
#
# This Dataset contains only single graph, but it samples negative edges based on time step,
# e.g. sample (u, v) only if
# 1. (u, v) is not an edge
# 2. u.time_step = v .time_step

# %%
import random

def sample_same_timestep_negative_edges(data: Data, neg_per_pos=1):
    node_time = data.node_time
    edge_index = data.edge_index
    num_nodes = data.num_nodes

    # Step 1: Build positive edge list
    pos_edge_index = edge_index

    # Step 2: Group node indices by time
    time_to_nodes = {}
    for t in torch.unique(node_time):
        nodes = (node_time == t).nonzero(as_tuple=True)[0].tolist()
        time_to_nodes[t.item()] = nodes

    # Step 3: Build a set of existing edges for quick lookup
    existing_edges = set((u.item(), v.item()) for u, v in edge_index.t())

    # Step 4: Sample negative edges within each timestep
    neg_edges = []
    max_trials = 10 * len(nodes) ** 2  # safeguard to avoid infinite loop     

    for t, nodes in time_to_nodes.items():
        trials = 0
        sampled = 0
        while sampled < neg_per_pos * len(pos_edge_index[0]) and trials < max_trials:
            u, v = random.sample(nodes, 2)
            if (u, v) not in existing_edges and (v, u) not in existing_edges and u != v:
                neg_edges.append((u, v))
                sampled += 1
            trials += 1

    # Step 5: Convert to tensors
    neg_edge_index = torch.tensor(neg_edges, dtype=torch.long).t()
    pos_edge_label = torch.ones(pos_edge_index.size(1), dtype=torch.float)
    neg_edge_label = torch.zeros(neg_edge_index.size(1), dtype=torch.float)

    edge_label_index = torch.cat([pos_edge_index, neg_edge_index], dim=1)
    edge_label = torch.cat([pos_edge_label, neg_edge_label], dim=0)

    return edge_label_index, edge_label

# %%
edge_label_index, edge_label = sample_same_timestep_negative_edges(data, neg_per_pos=1)

# %%
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv, GAE
from sklearn.metrics import f1_score, precision_score, recall_score


# 2) Encoder + Classifier
class GAEEncoder(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        return self.conv2(x, edge_index)
    
in_feats    = data.num_node_features
hidden_dim  = 128
out_dim     = 64
num_classes = int(data.y[data.y != 2].max() + 1)

encoder    = GAEEncoder(in_feats, hidden_dim, out_dim)
gae_model  = GAE(encoder)

optimizer = torch.optim.Adam(
    list(gae_model.parameters()),
    lr=0.001
)
bce_loss = torch.nn.BCEWithLogitsLoss()



epochs = 100
for epoch in range(1, epochs+1):
    _ = gae_model.train()
    optimizer.zero_grad()

    z = gae_model.encode(data.x, data.edge_index)  # Full graph for encoder
    logits = gae_model.decode(z, edge_label_index).view(-1)
    loss = F.binary_cross_entropy_with_logits(logits, edge_label)

    loss.backward()
    optimizer.step()

    print(f"Epoch {epoch:03d} | Loss: {loss.item():.4f}")
# Out:
# Epoch 001 | Loss: 1.2658
# Epoch 002 | Loss: 1.2377
# Epoch 003 | Loss: 1.2020
# Epoch 004 | Loss: 1.1634
# Epoch 005 | Loss: 1.1254
# Epoch 006 | Loss: 1.0905
# Epoch 007 | Loss: 1.0604
# Epoch 008 | Loss: 1.0363
# Epoch 009 | Loss: 1.0184
# Epoch 010 | Loss: 1.0061
# Epoch 011 | Loss: 0.9984
# Epoch 012 | Loss: 0.9944
# Epoch 013 | Loss: 0.9928
# Epoch 014 | Loss: 0.9928
# Epoch 015 | Loss: 0.9936
# Epoch 016 | Loss: 0.9944
# Epoch 017 | Loss: 0.9950
# Epoch 018 | Loss: 0.9950
# Epoch 019 | Loss: 0.9945
# Epoch 020 | Loss: 0.9933
# Epoch 021 | Loss: 0.9916
# Epoch 022 | Loss: 0.9896
# Epoch 023 | Loss: 0.9874
# Epoch 024 | Loss: 0.9850
# Epoch 025 | Loss: 0.9827
# Epoch 026 | Loss: 0.9805
# Epoch 027 | Loss: 0.9784
# Epoch 028 | Loss: 0.9765
# Epoch 029 | Loss: 0.9748
# Epoch 030 | Loss: 0.9734
# Epoch 031 | Loss: 0.9721
# Epoch 032 | Loss: 0.9709
# Epoch 033 | Loss: 0.9699
# Epoch 034 | Loss: 0.9689
# Epoch 035 | Loss: 0.9680
# Epoch 036 | Loss: 0.9670
# Epoch 037 | Loss: 0.9661
# Epoch 038 | Loss: 0.9651
# Epoch 039 | Loss: 0.9641
# Epoch 040 | Loss: 0.9630
# Epoch 041 | Loss: 0.9619
# Epoch 042 | Loss: 0.9608
# Epoch 043 | Loss: 0.9597
# Epoch 044 | Loss: 0.9586
# Epoch 045 | Loss: 0.9575
# Epoch 046 | Loss: 0.9565
# Epoch 047 | Loss: 0.9554
# Epoch 048 | Loss: 0.9545
# Epoch 049 | Loss: 0.9535
# Epoch 050 | Loss: 0.9526
# Epoch 051 | Loss: 0.9516
# Epoch 052 | Loss: 0.9507
# Epoch 053 | Loss: 0.9498
# Epoch 054 | Loss: 0.9489
# Epoch 055 | Loss: 0.9480
# Epoch 056 | Loss: 0.9471
# Epoch 057 | Loss: 0.9462
# Epoch 058 | Loss: 0.9453
# Epoch 059 | Loss: 0.9444
# Epoch 060 | Loss: 0.9435
# Epoch 061 | Loss: 0.9427
# Epoch 062 | Loss: 0.9419
# Epoch 063 | Loss: 0.9410
# Epoch 064 | Loss: 0.9403
# Epoch 065 | Loss: 0.9395
# Epoch 066 | Loss: 0.9388
# Epoch 067 | Loss: 0.9380
# Epoch 068 | Loss: 0.9373
# Epoch 069 | Loss: 0.9366
# Epoch 070 | Loss: 0.9358
# Epoch 071 | Loss: 0.9351
# Epoch 072 | Loss: 0.9344
# Epoch 073 | Loss: 0.9337
# Epoch 074 | Loss: 0.9329
# Epoch 075 | Loss: 0.9322
# Epoch 076 | Loss: 0.9316
# Epoch 077 | Loss: 0.9309
# Epoch 078 | Loss: 0.9302
# Epoch 079 | Loss: 0.9296
# Epoch 080 | Loss: 0.9289
# Epoch 081 | Loss: 0.9283
# Epoch 082 | Loss: 0.9276
# Epoch 083 | Loss: 0.9270
# Epoch 084 | Loss: 0.9263
# Epoch 085 | Loss: 0.9257
# Epoch 086 | Loss: 0.9251
# Epoch 087 | Loss: 0.9245
# Epoch 088 | Loss: 0.9238
# Epoch 089 | Loss: 0.9232
# Epoch 090 | Loss: 0.9226
# Epoch 091 | Loss: 0.9220
# Epoch 092 | Loss: 0.9214
# Epoch 093 | Loss: 0.9208
# Epoch 094 | Loss: 0.9202
# Epoch 095 | Loss: 0.9196
# Epoch 096 | Loss: 0.9190
# Epoch 097 | Loss: 0.9184
# Epoch 098 | Loss: 0.9178
# Epoch 099 | Loss: 0.9172
# Epoch 100 | Loss: 0.9167

# %% [markdown]
# ## (iii) Temporal Graph Dataset
# This dataset contain all sub-graphs from 1 ~ 49, with each sampled negative edges separately, note that currently sub-graph start from 42 is `None` due to no edge issue

# %%
import torch
import random
from torch_geometric.data import Data, InMemoryDataset
from torch_geometric.transforms import RandomLinkSplit

class PerTimestepEdgeLabelDataset(InMemoryDataset):
    def __init__(self, data: Data, neg_sampling_ratio=1.0):
        super().__init__("/tmp")
        self.data_list = []

        for t in torch.unique(data.node_time):

            # # sub-graph from time step 42 has no edges
            # if t >= 42:
            #     break
            
            # print(f"t = {t}")
            subgraph_t = self.build_subgraph(data, t)
            # print(f"sub-graph{t}: {subgraph_t}")
            train_data_t = self.random_split(subgraph_t, neg_sampling_ratio=neg_sampling_ratio)
            
            self.data_list.append(train_data_t)

    def build_subgraph(self, data, time_step):

        node_mask = data.node_time == time_step
        # no nodes at this time step
        if node_mask.sum() == 0:
            return None

        src, dst = data.edge_index
        edge_mask = node_mask[src] & node_mask[dst]
        edge_index_t = data.edge_index[:, edge_mask]
        node_indices = node_mask.nonzero(as_tuple=True)[0]

        # keep x, y whose time step = time_step
        x_t, y_t = data.x[node_indices], data.y[node_indices]
        node_time_t = data.node_time[node_indices]

        # 建圖時重新編號節點 (Optional: for cleaner subgraph)
        index_map = torch.full((data.num_nodes,), -1, dtype=torch.long)
        index_map[node_indices] = torch.arange(node_indices.size(0))
        edge_index_t = index_map[edge_index_t]

        return Data(
            x=x_t,
            y=y_t,
            edge_index=edge_index_t,    
            num_nodes=node_indices.size(0),
            node_time=node_time_t,
        )
        

    def random_split(self, data, neg_sampling_ratio=1.0):
        splitter = RandomLinkSplit(
            is_undirected=False,
            split_labels=False,
            add_negative_train_samples=True,
            neg_sampling_ratio=neg_sampling_ratio,
            num_val=0,
            num_test=0,
        )
        try:
            train_data_t, _, _ = splitter(data)
            # print(train_data_t)
            assert isinstance(train_data_t, Data)
            return train_data_t
        except Exception as e:
            print(f"Skipping timestep {data.node_time[0]} due to error: {e}")
            return None


    def hard_negative_split(self, data, neg_sampling_ratio=1, k_hop_neighbors=1):
        from torch_geometric.utils import k_hop_subgraph

        edge_index = data.edge_index
        node_time = data.node_time
        pos_edge_index = edge_index
        existing_edges = set((u.item(), v.item()) for u, v in edge_index.t())

        neg_edges = []
        for u in range(data.num_nodes):
            if len(neg_edges) >= neg_sampling_ratio * edge_index.size(1):
                break
            # Get k-hop neighbors of u
            subset, _, _, _ = k_hop_subgraph(u, num_hops=k_hop_neighbors, edge_index=edge_index, relabel_nodes=False)
            neighbors = set(subset.tolist())
            candidates = set(range(data.num_nodes)) - neighbors - {u}
            if len(candidates) == 0:
                continue
            v = random.choice(list(candidates))
            if (u, v) not in existing_edges and (v, u) not in existing_edges:
                neg_edges.append((u, v))

        if len(neg_edges) == 0:
            return None  # skip empty

        neg_edge_index = torch.tensor(neg_edges, dtype=torch.long).t()
        pos_edge_label = torch.ones(pos_edge_index.size(1), dtype=torch.float)
        neg_edge_label = torch.zeros(neg_edge_index.size(1), dtype=torch.float)

        edge_label_index = torch.cat([pos_edge_index, neg_edge_index], dim=1)
        edge_label = torch.cat([pos_edge_label, neg_edge_label], dim=0)

        return Data(
            x=data.x,
            edge_index=data.edge_index,
            edge_label_index=edge_label_index,
            edge_label=edge_label,
            node_time=data.node_time,
        )


    def __len__(self):
        return len(self.data_list)

    def __getitem__(self, idx):
        return self.data_list[idx]

# %%
from torch_geometric.loader import DataLoader

dataset = PerTimestepEdgeLabelDataset(data, neg_sampling_ratio=1.0)
loader = DataLoader(dataset, batch_size=1, shuffle=False)
# Out:
# Skipping timestep 42 due to error: Insufficient number of edges for training
# Skipping timestep 43 due to error: Insufficient number of edges for training
# Skipping timestep 44 due to error: Insufficient number of edges for training
# Skipping timestep 45 due to error: Insufficient number of edges for training
# Skipping timestep 46 due to error: Insufficient number of edges for training
# Skipping timestep 47 due to error: Insufficient number of edges for training
# Skipping timestep 48 due to error: Insufficient number of edges for training
# Skipping timestep 49 due to error: Insufficient number of edges for training

# %%
import torch
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize_tsne_binary(model, data, stage='before'):
    model.eval()
    with torch.no_grad():
        z = model(data.x, data.edge_index)

    # 🟢 Filter nodes with class 0 or 1
    mask = (data.y == 0) | (data.y == 1)
    if mask.sum() == 0:
        raise ValueError("No nodes with label 0 or 1 found.")
        
    z_filtered = z[mask]
    y_filtered = data.y[mask]

    # 🔵 Convert to CPU numpy arrays
    z_np = z_filtered.detach().cpu().numpy()
    y_np = y_filtered.detach().cpu().numpy()

    # 🟥 Map y=0 → green, y=1 → red
    color_map = np.where(y_np == 0, 'green', 'red')

    # 🔵 t-SNE projection
    tsne = TSNE(n_components=2, random_state=42)
    z_2d = tsne.fit_transform(z_np)

    # 🔴 Plot
    plt.figure(figsize=(8, 6))
    for label, color in zip([0, 1], ['green', 'red']):
        idx = y_np == label
        plt.scatter(z_2d[idx, 0], z_2d[idx, 1], c=color, label=f"Class {label}", s=10)

    plt.legend()
    plt.title(f"t-SNE of Embeddings for Class 0 (green) and 1 (red) ({stage} training)")
    plt.show()

# %% [markdown]
# ### Test on subgraph 1 (time step = 1)

# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch_geometric.nn import GCNConv, GAE
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score

# Define Encoder
class GAEEncoder(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        return self.conv2(x, edge_index)

# Model & Optimizer
in_feats = data.num_node_features
hidden_dim = 256
out_dim = 128
encoder = GAEEncoder(in_feats, hidden_dim, out_dim)
gae_model = GAE(encoder)
optimizer = torch.optim.Adam(gae_model.parameters(), lr=0.0001)
bce_loss = torch.nn.BCEWithLogitsLoss()

# Get training subgraph (time step 1)
train_batch = dataset[0]

visualize_tsne_binary(gae_model, train_batch, stage='before')

def train_single_graph(train_batch):

    loss_list, auc_list, f1_list, precision_list, recall_list = [], [], [], [], []
    epochs = 300

    for epoch in range(1, epochs + 1):
        _ = gae_model.train()
        optimizer.zero_grad()

        # Forward
        z = gae_model.encode(train_batch.x.squeeze(0), train_batch.edge_index.squeeze(0))
        edge_label_index = train_batch.edge_label_index.squeeze(0)
        edge_label = train_batch.edge_label.squeeze(0).float()
        logits = gae_model.decode(z, edge_label_index).view(-1)

        # Loss
        loss = bce_loss(logits, edge_label)
        loss.backward()
        optimizer.step()

        # Evaluation
        with torch.no_grad():
            probs = torch.sigmoid(logits).cpu()
            # print(f"probs: {probs}")
            # print(f"edge_label_index: {edge_label_index}")
            preds = (probs > 0.5).float()
            labels = edge_label.cpu()

            auc = roc_auc_score(labels, probs)
            f1 = f1_score(labels, preds)
            precision = precision_score(labels, preds)
            recall = recall_score(labels, preds)

            # Save metrics
            loss_list.append(loss.item())
            auc_list.append(auc)
            f1_list.append(f1)
            precision_list.append(precision)
            recall_list.append(recall)

            print(f"Epoch {epoch:03d} | Loss: {loss.item():.4f} | AUC: {auc:.4f} | F1: {f1:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f}")
    
    return loss_list, auc_list, f1_list, precision_list, recall_list

loss_list, auc_list, f1_list, precision_list, recall_list = train_single_graph(train_batch)
# Out:
# Epoch 001 | Loss: 0.8132 | AUC: 0.5902 | F1: 0.6667 | Precision: 0.5000 | Recall: 1.0000
# Epoch 002 | Loss: 0.8132 | AUC: 0.5983 | F1: 0.6667 | Precision: 0.5000 | Recall: 1.0000
# Epoch 003 | Loss: 0.8132 | AUC: 0.6060 | F1: 0.6667 | Precision: 0.5000 | Recall: 1.0000
# Epoch 004 | Loss: 0.8132 | AUC: 0.6136 | F1: 0.6667 | Precision: 0.5000 | Recall: 1.0000
# Epoch 005 | Loss: 0.8131 | AUC: 0.6222 | F1: 0.6667 | Precision: 0.5000 | Recall: 1.0000
# Epoch 006 | Loss: 0.8131 | AUC: 0.6298 | F1: 0.6667 | Precision: 0.5000 | Recall: 1.0000
# Epoch 007 | Loss: 0.8130 | AUC: 0.6375 | F1: 0.6667 | Precision: 0.5000 | Recall: 1.0000
# Epoch 008 | Loss: 0.8130 | AUC: 0.6449 | F1: 0.6667 | Precision: 0.5000 | Recall: 1.0000
# Epoch 009 | Loss: 0.8128 | AUC: 0.6510 | F1: 0.6667 | Precision: 0.5000 | Recall: 1.0000
# Epoch 010 | Loss: 0.8127 | AUC: 0.6579 | F1: 0.6667 | Precision: 0.5000 | Recall: 1.0000
# Epoch 286 | Loss: 0.6198 | AUC: 0.8850 | F1: 0.6750 | Precision: 0.5102 | Recall: 0.9971
# Epoch 287 | Loss: 0.6196 | AUC: 0.8851 | F1: 0.6749 | Precision: 0.5101 | Recall: 0.9970
# Epoch 288 | Loss: 0.6195 | AUC: 0.8852 | F1: 0.6750 | Precision: 0.5102 | Recall: 0.9970
# Epoch 289 | Loss: 0.6194 | AUC: 0.8853 | F1: 0.6749 | Precision: 0.5101 | Recall: 0.9970
# Epoch 290 | Loss: 0.6193 | AUC: 0.8854 | F1: 0.6749 | Precision: 0.5101 | Recall: 0.9970
# Epoch 291 | Loss: 0.6191 | AUC: 0.8855 | F1: 0.6750 | Precision: 0.5102 | Recall: 0.9970
# Epoch 292 | Loss: 0.6190 | AUC: 0.8856 | F1: 0.6749 | Precision: 0.5101 | Recall: 0.9970
# Epoch 293 | Loss: 0.6189 | AUC: 0.8857 | F1: 0.6749 | Precision: 0.5101 | Recall: 0.9970
# Epoch 294 | Loss: 0.6188 | AUC: 0.8858 | F1: 0.6749 | Precision: 0.5101 | Recall: 0.9971
# Epoch 295 | Loss: 0.6187 | AUC: 0.8859 | F1: 0.6749 | Precision: 0.5101 | Recall: 0.9971
# Epoch 296 | Loss: 0.6186 | AUC: 0.8860 | F1: 0.6750 | Precision: 0.5101 | Recall: 0.9971
# Epoch 297 | Loss: 0.6184 | AUC: 0.8861 | F1: 0.6750 | Precision: 0.5101 | Recall: 0.9971
# Epoch 298 | Loss: 0.6183 | AUC: 0.8862 | F1: 0.6750 | Precision: 0.5101 | Recall: 0.9971
# Epoch 299 | Loss: 0.6182 | AUC: 0.8863 | F1: 0.6750 | Precision: 0.5102 | Recall: 0.9971
# Epoch 300 | Loss: 0.6181 | AUC: 0.8864 | F1: 0.6751 | Precision: 0.5103 | Recall: 0.9970

# %%
visualize_tsne_binary(gae_model, train_batch, stage='after')

# %%
plt.figure(figsize=(12, 6))
plt.plot(loss_list, label='Loss')
plt.plot(auc_list, label='AUC')
plt.plot(f1_list, label='F1')
plt.plot(precision_list, label='Precision')
plt.plot(recall_list, label='Recall')
plt.xlabel("Epoch")
plt.ylabel("Metric Value")
plt.title("Training Metrics Over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
with torch.no_grad():
    _ = gae_model.eval()
    z = gae_model.encode(train_batch.x.squeeze(0), train_batch.edge_index.squeeze(0))
    logits = gae_model.decode(z, train_batch.edge_label_index.squeeze(0)).view(-1)
    probs = torch.sigmoid(logits).cpu()
    
    print(f"Min score: {probs.min().item():.4f}, Max score: {probs.max().item():.4f}")
    print(f"Fraction > 0.5: {(probs > 0.5).float().mean().item():.4f}")
    labels = train_batch.edge_label.squeeze(0).cpu()

    real_scores = probs[labels == 1]
    fake_scores = probs[labels == 0]

    plt.hist(real_scores.numpy(), bins=50, alpha=0.6, label='Real Edges')
    plt.hist(fake_scores.numpy(), bins=50, alpha=0.6, label='Fake Edges')
    plt.xlabel("Predicted Score")
    plt.ylabel("Count")
    plt.title("Score Distribution")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Min score: 0.5000, Max score: 0.7311
# Fraction > 0.5: 0.9768

# %% [markdown]
# ## Train on all sub-graph (1 ~ 41 only)
#
# 300 epochs for each sub-graph

# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch_geometric.nn import GCNConv, GATConv, GAE
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score

# Define Encoder
class GAEEncoder(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        return self.conv2(x, edge_index)

class GATEncoder(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, heads=1, dropout=0.6):
        super().__init__()
        self.conv1 = GATConv(in_channels, hidden_channels, heads=heads, dropout=dropout)
        self.conv2 = GATConv(hidden_channels * heads, out_channels, heads=1, concat=False, dropout=dropout)

    def forward(self, x, edge_index):
        x = F.elu(self.conv1(x, edge_index))
        return self.conv2(x, edge_index)  # latent embedding z

# Model & Optimizer
in_feats = data.num_node_features
print(f"Number of node features: {in_feats}")
hidden_dim = 128
out_dim = 64
encoder = GAEEncoder(in_feats, hidden_dim, out_dim)
gae_model = GAE(encoder)
optimizer = torch.optim.Adam(gae_model.parameters(), lr=0.0001)
bce_loss = torch.nn.BCEWithLogitsLoss()

def train_single_graph(train_batch):

    loss_list, auc_list, f1_list, precision_list, recall_list = [], [], [], [], []
    epochs = 300

    for epoch in range(1, epochs + 1):
        _ = gae_model.train()
        optimizer.zero_grad()

        # Forward
        z = gae_model.encode(train_batch.x.squeeze(0), train_batch.edge_index.squeeze(0))
        edge_label_index = train_batch.edge_label_index.squeeze(0)
        edge_label = train_batch.edge_label.squeeze(0).float()
        logits = gae_model.decode(z, edge_label_index).view(-1)

        # Loss
        loss = bce_loss(logits, edge_label)
        loss.backward()
        optimizer.step()

        # Evaluation
        with torch.no_grad():
            probs = torch.sigmoid(logits).cpu()
            preds = (probs > 0.5).float()
            labels = edge_label.cpu()

            auc = roc_auc_score(labels, probs)
            f1 = f1_score(labels, preds)
            precision = precision_score(labels, preds)
            recall = recall_score(labels, preds)

            # Save metrics
            loss_list.append(loss.item())
            auc_list.append(auc)
            f1_list.append(f1)
            precision_list.append(precision)
            recall_list.append(recall)

            # print(f"probs: {probs}")
            # print(f"edge_label_index: {edge_label_index}")
            # print(f"Epoch {epoch:03d} | Loss: {loss.item():.4f} | AUC: {auc:.4f} | F1: {f1:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f}")
    
    return loss_list, auc_list, f1_list, precision_list, recall_list

# print(train_batch)
for t, train_batch in enumerate(dataset):
    if t > 40: break
    print(f"t={t}, train_batch={train_batch}")
    loss_list, auc_list, f1_list, precision_list, recall_list = train_single_graph(train_batch)
# Out:
# Number of node features: 182
# t=0, train_batch=Data(x=[7844, 182], edge_index=[2, 7317], y=[7844], num_nodes=7844, node_time=[7844], edge_label=[14634], edge_label_index=[2, 14634])
# t=1, train_batch=Data(x=[4529, 182], edge_index=[2, 2998], y=[4529], num_nodes=4529, node_time=[4529], edge_label=[5996], edge_label_index=[2, 5996])
# t=2, train_batch=Data(x=[6621, 182], edge_index=[2, 4819], y=[6621], num_nodes=6621, node_time=[6621], edge_label=[9638], edge_label_index=[2, 9638])
# t=3, train_batch=Data(x=[5689, 182], edge_index=[2, 3953], y=[5689], num_nodes=5689, node_time=[5689], edge_label=[7906], edge_label_index=[2, 7906])
# t=4, train_batch=Data(x=[6801, 182], edge_index=[2, 4972], y=[6801], num_nodes=6801, node_time=[6801], edge_label=[9944], edge_label_index=[2, 9944])
# t=5, train_batch=Data(x=[4328, 182], edge_index=[2, 2914], y=[4328], num_nodes=4328, node_time=[4328], edge_label=[5828], edge_label_index=[2, 5828])
# t=6, train_batch=Data(x=[6026, 182], edge_index=[2, 5263], y=[6026], num_nodes=6026, node_time=[6026], edge_label=[10526], edge_label_index=[2, 10526])
# t=7, train_batch=Data(x=[4431, 182], edge_index=[2, 2294], y=[4431], num_nodes=4431, node_time=[4431], edge_label=[4588], edge_label_index=[2, 4588])
# t=8, train_batch=Data(x=[4991, 182], edge_index=[2, 2408], y=[4991], num_nodes=4991, node_time=[4991], edge_label=[4816], edge_label_index=[2, 4816])
# t=9, train_batch=Data(x=[6727, 182], edge_index=[2, 5154], y=[6727], num_nodes=6727, node_time=[6727], edge_label=[10308], edge_label_index=[2, 10308])
# t=10, train_batch=Data(x=[4289, 182], edge_index=[2, 3509], y=[4289], num_nodes=4289, node_time=[4289], edge_label=[7018], edge_label_index=[2, 7018])
# t=11, train_batch=Data(x=[2039, 182], edge_index=[2, 1055], y=[2039], num_nodes=2039, node_time=[2039], edge_label=[2110], edge_label_index=[2, 2110])
# t=12, train_batch=Data(x=[4516, 182], edge_index=[2, 3048], y=[4516], num_nodes=4516, node_time=[4516], edge_label=[6096], edge_label_index=[2, 6096])
# t=13, train_batch=Data(x=[2020, 182], edge_index=[2, 860], y=[2020], num_nodes=2020, node_time=[2020], edge_label=[1720], edge_label_index=[2, 1720])
# t=14, train_batch=Data(x=[3623, 182], edge_index=[2, 1940], y=[3623], num_nodes=3623, node_time=[3623], edge_label=[3880], edge_label_index=[2, 3880])
# t=15, train_batch=Data(x=[2963, 182], edge_index=[2, 1335], y=[2963], num_nodes=2963, node_time=[2963], edge_label=[2670], edge_label_index=[2, 2670])
# t=16, train_batch=Data(x=[3373, 182], edge_index=[2, 1587], y=[3373], num_nodes=3373, node_time=[3373], edge_label=[3174], edge_label_index=[2, 3174])
# t=17, train_batch=Data(x=[1969, 182], edge_index=[2, 617], y=[1969], num_nodes=1969, node_time=[1969], edge_label=[1234], edge_label_index=[2, 1234])
# t=18, train_batch=Data(x=[3506, 182], edge_index=[2, 2884], y=[3506], num_nodes=3506, node_time=[3506], edge_label=[5768], edge_label_index=[2, 5768])
# t=19, train_batch=Data(x=[4287, 182], edge_index=[2, 3601], y=[4287], num_nodes=4287, node_time=[4287], edge_label=[7202], edge_label_index=[2, 7202])
# t=20, train_batch=Data(x=[3534, 182], edge_index=[2, 2308], y=[3534], num_nodes=3534, node_time=[3534], edge_label=[4616], edge_label_index=[2, 4616])
# t=21, train_batch=Data(x=[5878, 182], edge_index=[2, 4414], y=[5878], num_nodes=5878, node_time=[5878], edge_label=[8828], edge_label_index=[2, 8828])
# t=22, train_batch=Data(x=[4132, 182], edge_index=[2, 2840], y=[4132], num_nodes=4132, node_time=[4132], edge_label=[5680], edge_label_index=[2, 5680])
# t=23, train_batch=Data(x=[4580, 182], edge_index=[2, 3183], y=[4580], num_nodes=4580, node_time=[4580], edge_label=[6366], edge_label_index=[2, 6366])
# t=24, train_batch=Data(x=[2307, 182], edge_index=[2, 1038], y=[2307], num_nodes=2307, node_time=[2307], edge_label=[2076], edge_label_index=[2, 2076])
# t=25, train_batch=Data(x=[2519, 182], edge_index=[2, 1038], y=[2519], num_nodes=2519, node_time=[2519], edge_label=[2076], edge_label_index=[2, 2076])
# t=26, train_batch=Data(x=[1077, 182], edge_index=[2, 218], y=[1077], num_nodes=1077, node_time=[1077], edge_label=[436], edge_label_index=[2, 436])
# t=27, train_batch=Data(x=[1652, 182], edge_index=[2, 505], y=[1652], num_nodes=1652, node_time=[1652], edge_label=[1010], edge_label_index=[2, 1010])
# t=28, train_batch=Data(x=[4266, 182], edge_index=[2, 3433], y=[4266], num_nodes=4266, node_time=[4266], edge_label=[6866], edge_label_index=[2, 6866])
# t=29, train_batch=Data(x=[2475, 182], edge_index=[2, 671], y=[2475], num_nodes=2475, node_time=[2475], edge_label=[1342], edge_label_index=[2, 1342])
# t=30, train_batch=Data(x=[2775, 182], edge_index=[2, 1201], y=[2775], num_nodes=2775, node_time=[2775], edge_label=[2402], edge_label_index=[2, 2402])
# t=31, train_batch=Data(x=[4513, 182], edge_index=[2, 2901], y=[4513], num_nodes=4513, node_time=[4513], edge_label=[5802], edge_label_index=[2, 5802])
# t=32, train_batch=Data(x=[3148, 182], edge_index=[2, 1426], y=[3148], num_nodes=3148, node_time=[3148], edge_label=[2852], edge_label_index=[2, 2852])
# t=33, train_batch=Data(x=[2436, 182], edge_index=[2, 1266], y=[2436], num_nodes=2436, node_time=[2436], edge_label=[2532], edge_label_index=[2, 2532])
# t=34, train_batch=Data(x=[5486, 182], edge_index=[2, 4439], y=[5486], num_nodes=5486, node_time=[5486], edge_label=[8878], edge_label_index=[2, 8878])
# t=35, train_batch=Data(x=[6276, 182], edge_index=[2, 5095], y=[6276], num_nodes=6276, node_time=[6276], edge_label=[10190], edge_label_index=[2, 10190])
# t=36, train_batch=Data(x=[3244, 182], edge_index=[2, 1708], y=[3244], num_nodes=3244, node_time=[3244], edge_label=[3416], edge_label_index=[2, 3416])
# t=37, train_batch=Data(x=[2874, 182], edge_index=[2, 1911], y=[2874], num_nodes=2874, node_time=[2874], edge_label=[3822], edge_label_index=[2, 3822])
# t=38, train_batch=Data(x=[2717, 182], edge_index=[2, 1237], y=[2717], num_nodes=2717, node_time=[2717], edge_label=[2474], edge_label_index=[2, 2474])
# t=39, train_batch=Data(x=[4458, 182], edge_index=[2, 3272], y=[4458], num_nodes=4458, node_time=[4458], edge_label=[6544], edge_label_index=[2, 6544])
# t=40, train_batch=Data(x=[5312, 182], edge_index=[2, 3476], y=[5312], num_nodes=5312, node_time=[5312], edge_label=[6952], edge_label_index=[2, 6952])

# %%
train_mask = (data.y != 2) & data.train_mask
test_mask  = (data.y != 2) & data.test_mask

y_train = data.y[train_mask].cpu().numpy()
y_test  = data.y[test_mask].cpu().numpy()

# %% [markdown]
# ### RF classifier with only GNE (GAE Node Embedding)

# %%
import torch
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


# get node embeddings
gae_model.eval()  # Important: turn off dropout etc. during inference
with torch.no_grad():
    z = gae_model.encode(data.x, data.edge_index)  # z is of shape [num_nodes, out_dim]


X_train = z[train_mask].cpu().numpy()
X_test  = z[test_mask].cpu().numpy()

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

acc  = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred, average='macro')
rec  = recall_score(y_test, y_pred, average='macro')
f1   = f1_score(y_test, y_pred, average='macro')

print(f"Random Forest - Acc: {acc:.4f}, Prec: {prec:.4f}, Rec: {rec:.4f}, F1: {f1:.4f}")
# Out:
# Random Forest - Acc: 0.9405, Prec: 0.8826, Rec: 0.5637, F1: 0.5963

# %% [markdown]
# ### RF classifier with GNE + AF
# - If GAE is trained on PCA-reduced feature space (e.g. 50), execute the following cell to re-construct `data` with original AF
# - If GAE is trained on original feature space, skip the following cell

# %%
df_txs_features_final = df_txs_features_processed.drop(columns=['class', 'Time step'])

x = torch.tensor(df_txs_features_final.values, dtype=torch.float)
data = Data(x=x, edge_index=edge_index, y=y, train_mask=train_mask, test_mask=test_mask, node_time=time_steps)
data.y = torch.from_numpy(data.y.to_numpy().astype(int)).long()
data
# Out:
# Data(x=[202804, 182], edge_index=[2, 233283], y=[202804], train_mask=[202804], test_mask=[202804], node_time=[202804])

# %%
z_augmented = torch.cat([data.x, z], dim=1)  # shape: [202804, 310]

print(f"z_augmented.shape: {z_augmented.shape}")

X_train_aug = z_augmented[train_mask].cpu().numpy()
X_test_aug  = z_augmented[test_mask].cpu().numpy()

rf_aug = RandomForestClassifier(n_estimators=100, random_state=42)
rf_aug.fit(X_train_aug, y_train)

y_pred_aug = rf_aug.predict(X_test_aug)

acc  = accuracy_score(y_test, y_pred_aug)
prec = precision_score(y_test, y_pred_aug, pos_label=1)
rec  = recall_score(y_test, y_pred_aug, pos_label=1)
f1   = f1_score(y_test, y_pred_aug, pos_label=1)

print(f"Random Forest - Acc: {acc:.4f}, Prec: {prec:.4f}, Rec: {rec:.4f}, F1: {f1:.4f}")
# Out:
# Random Forest - Acc: 0.9800, Prec: 0.9690, Rec: 0.7211, F1: 0.8269

# %% [markdown]
# ### RF Classifier with only AF

# %%
import torch
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

X_train_af = data.x[train_mask].cpu().numpy()
X_test_af  = data.x[test_mask].cpu().numpy()

rf_af = RandomForestClassifier(n_estimators=100, random_state=42)
rf_af.fit(X_train_af, y_train)

y_pred_af = rf_af.predict(X_test_af)

acc  = accuracy_score(y_test, y_pred_af)
prec = precision_score(y_test, y_pred_af, pos_label=1)
rec  = recall_score(y_test, y_pred_af, pos_label=1)
f1   = f1_score(y_test, y_pred_af, pos_label=1)

print(f"Random Forest - Acc: {acc:.4f}, Prec: {prec:.4f}, Rec: {rec:.4f}, F1: {f1:.4f}")
# Out:
# Random Forest - Acc: 0.9799, Prec: 0.9678, Rec: 0.7211, F1: 0.8265

# %% [markdown]
# ## GAE, GCN

# %%
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv, GAE
from sklearn.metrics import f1_score, precision_score, recall_score

class NodeClassifier(torch.nn.Module):
    def __init__(self, in_channels, num_classes):
        super().__init__()
        self.lin = torch.nn.Linear(in_channels, num_classes)
    def forward(self, z):
        return self.lin(z)

in_feats    = data.num_node_features
hidden_dim  = 256
out_dim     = 128
num_classes = int(data.y[data.y != 2].max() + 1)

classifier = NodeClassifier(out_dim, num_classes)

optimizer = torch.optim.Adam(
    list(classifier.parameters()),
    lr=0.001
)
ce_loss  = torch.nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(classifier.parameters(), lr=0.01)
loss_fn = torch.nn.CrossEntropyLoss()

# get node embeddings
gae_model.eval()  # Important: turn off dropout etc. during inference
with torch.no_grad():
    z = gae_model.encode(data.x, data.edge_index)  # z is of shape [num_nodes, out_dim]

# training loop
for epoch in range(300):
    classifier.train()
    optimizer.zero_grad()
    out = classifier(z)  # shape [num_nodes, num_classes]
    train_mask = (data.y != 2) & data.train_mask
    loss = loss_fn(out[train_mask], data.y[train_mask])
    loss.backward()
    optimizer.step()

    print(f"Epoch {epoch}, Loss: {loss.item():.4f}")

classifier.eval()
with torch.no_grad():
    out = classifier(z)
    pred = out.argmax(dim=1)
    test_mask = (data.y != 2) & data.test_mask
    acc = (pred[test_mask] == data.y[test_mask]).float().mean()
    prec = precision_score(data.y[test_mask], pred[test_mask], average='macro')
    rec  = recall_score(data.y[test_mask], pred[test_mask], average='macro')
    f1   = f1_score(data.y[test_mask], pred[test_mask], average='macro')
    print(f"Test Acc={acc:.4f} | "
            f"Precision={prec:.4f} | "
            f"Recall={rec:.4f} | "
            f"F1={f1:.4f}")
# Out:
# Epoch 0, Loss: 0.8139
# Epoch 1, Loss: 0.4654
# Epoch 2, Loss: 0.3829
# Epoch 3, Loss: 0.3674
# Epoch 4, Loss: 0.3713
# Epoch 5, Loss: 0.3794
# Epoch 6, Loss: 0.3857
# Epoch 7, Loss: 0.3882
# Epoch 8, Loss: 0.3870
# Epoch 9, Loss: 0.3830
# Epoch 10, Loss: 0.3772
# Epoch 11, Loss: 0.3710
# Epoch 12, Loss: 0.3657
# Epoch 13, Loss: 0.3621
# Epoch 14, Loss: 0.3605
# Epoch 15, Loss: 0.3602
# Epoch 16, Loss: 0.3599
# Epoch 17, Loss: 0.3584
# Epoch 18, Loss: 0.3551
# Epoch 19, Loss: 0.3501
# Epoch 20, Loss: 0.3442
# Epoch 21, Loss: 0.3382
# Epoch 22, Loss: 0.3330
# Epoch 23, Loss: 0.3288
# Epoch 24, Loss: 0.3254
# Epoch 25, Loss: 0.3226
# Epoch 26, Loss: 0.3200
# Epoch 27, Loss: 0.3172
# Epoch 28, Loss: 0.3141
# Epoch 29, Loss: 0.3110
# Epoch 30, Loss: 0.3079
# Epoch 31, Loss: 0.3051
# Epoch 32, Loss: 0.3027
# Epoch 33, Loss: 0.3008
# Epoch 34, Loss: 0.2991
# Epoch 35, Loss: 0.2974
# Epoch 36, Loss: 0.2958
# Epoch 37, Loss: 0.2940
# Epoch 38, Loss: 0.2922
# Epoch 39, Loss: 0.2907
# Epoch 40, Loss: 0.2895
# Epoch 41, Loss: 0.2887
# Epoch 42, Loss: 0.2881
# Epoch 43, Loss: 0.2876
